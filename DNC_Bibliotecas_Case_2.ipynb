# %% [markdown]
# <a href="https://colab.research.google.com/github/produtodnc/biblioteca_pandas/blob/main/DNC_Bibliotecas_Case_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PANDAS

# %%
import pandas as pd

# %%
retail = pd.read_excel('/content/varejo.xlsx')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-2-335a376a7d4b> in <cell line: 1>()
# ----> 1 retail = pd.read_excel('/content/varejo.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
#Exibe as primeiras linhas
retail.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055          APP        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
#
#        Nome_Departamento estado  cliente_Log
# 0  Telefones e Celulares     SP        15042
# 1                Tablets     SP        17590
# 2                  Bebes     SP        15478
# 3       TVs e Acessorios     SP         2933
# 4        Esporte e Lazer     RS        19790

# %%
cliente = pd.read_excel("cliente_varejo.xlsx")

# %%
#Exibe as últimas linhas
retail.tail()
# Out:
#        idcompra idcanalvenda bandeira       Data  Preço  Preço_com_frete  \
# 80223    636930   Aplicativo        B 2023-04-01  879.2            879.2
# 80224    658550   Aplicativo        B 2023-02-18  879.2            879.2
# 80225    680170   Aplicativo        B 2023-01-22  879.2            879.2
# 80226    701790   Aplicativo        B 2023-02-11  879.2            879.2
# 80227    723410   Aplicativo        B 2023-01-27  879.2            879.2
#
#            Nome_Departamento estado  cliente_Log
# 80223  Telefones e Celulares     RJ        15746
# 80224  Telefones e Celulares     AM          443
# 80225  Telefones e Celulares     PB         9349
# 80226  Telefones e Celulares     PB        10944
# 80227  Telefones e Celulares     PB        22242

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             79926 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
retail.groupby('idcanalvenda').idcompra.nunique()
# Out:
# idcanalvenda
# APP             139
# Aplicativo    21425
# Internet      24515
# Mobile        24732
# Name: idcompra, dtype: int64

# %%
retail['idcanalvenda'] = retail['idcanalvenda'].str.replace('APP','Aplicativo')

# %%
retail.groupby('idcanalvenda').idcompra.nunique()
# Out:
# idcanalvenda
# Aplicativo    21539
# Internet      24515
# Mobile        24732
# Name: idcompra, dtype: int64

# %%
retail.groupby('bandeira').idcompra.nunique()
# Out:
# bandeira
# A    27679
# B    38483
# Name: idcompra, dtype: int64

# %%
retail.groupby('Nome_Departamento').idcompra.nunique().sort_values(ascending=False)

# %%
retail.groupby('estado').idcompra.nunique().sort_values(ascending=False)

# %%
#Exibir os campos nulos em ligações feitas
retail[retail["estado"].isnull()]
# Out:
#        idcompra idcanalvenda bandeira       Data  Preço  Preço_com_frete  \
# 96       382380     Internet        A 2023-04-26    NaN          879.200
# 284      346055     Internet        A 2023-03-23    NaN           87.648
# 402      172555       Mobile        A 2023-03-19    NaN          135.840
# 411      446380       Mobile        A 2023-03-09    NaN         1703.120
# 770       40425       Mobile        B 2023-04-21    NaN         1759.200
# ...         ...          ...      ...        ...    ...              ...
# 78610    399680   Aplicativo        A 2023-04-19    NaN          339.912
# 78718    320895       Mobile        B 2023-01-20    NaN         1000.800
# 79465    389240   Aplicativo        A 2023-01-14    NaN          279.200
# 79548    124585       Mobile        A 2023-04-21    NaN         2051.240
# 80016    104235   Aplicativo        A 2023-04-17    NaN         1199.200
#
#            Nome_Departamento estado  cliente_Log
# ...

# %%
#Cria uma nova tabela e elimina os nulos da tabela
retail_sem_null = retail.dropna()
retail_sem_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79926 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           79926 non-null  int64
#  1   idcanalvenda       79926 non-null  object
#  2   bandeira           79926 non-null  object
#  3   Data               79926 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    79926 non-null  float64
#  6   Nome_Departamento  79926 non-null  object
#  7   estado             79926 non-null  object
#  8   cliente_Log        79926 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 6.1+ MB

# %%
#Remove valores nulos do dataframe original
retail.dropna(inplace = True)
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79926 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           79926 non-null  int64
#  1   idcanalvenda       79926 non-null  object
#  2   bandeira           79926 non-null  object
#  3   Data               79926 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    79926 non-null  float64
#  6   Nome_Departamento  79926 non-null  object
#  7   estado             79926 non-null  object
#  8   cliente_Log        79926 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 6.1+ MB

# %%
retail = pd.read_excel('/content/varejo.xlsx')

# %%
#Substitui os nulos por um valor específico
retail["estado"].fillna("MS", inplace = True)

# %%
retail.groupby('estado').idcompra.nunique().sort_values(ascending=False)
# Out:
# estado
# SP    25962
# RJ    16213
# MG    10538
# RS     4099
# PR     2754
# BA     2028
# SC     1932
# DF     1902
# PE     1632
# GO     1603
# ES     1254
# CE     1007
# PB      536
# MT      510
# RN      463
# AL      461
# SE      340
# MS      302
# PI      247
# MA      129
# PA      108
# TO      101
# RO       15
# AM       15
# AC       10
# RR        7
# AP        3
# Name: idcompra, dtype: int64

# %%
retail[retail["estado"].isnull()]
# Out:
# Empty DataFrame
# Columns: [idcompra, idcanalvenda, bandeira, Data, Preço, Preço_com_frete, Nome_Departamento, estado, cliente_Log]
# Index: []

# %%
retail[retail["Preço"].isnull()]
# Out:
#        idcompra idcanalvenda bandeira       Data  Preço  Preço_com_frete  \
# 96       382380     Internet        A 2023-04-26    NaN          879.200
# 284      346055     Internet        A 2023-03-23    NaN           87.648
# 402      172555       Mobile        A 2023-03-19    NaN          135.840
# 411      446380       Mobile        A 2023-03-09    NaN         1703.120
# 770       40425       Mobile        B 2023-04-21    NaN         1759.200
# ...         ...          ...      ...        ...    ...              ...
# 78610    399680   Aplicativo        A 2023-04-19    NaN          339.912
# 78718    320895       Mobile        B 2023-01-20    NaN         1000.800
# 79465    389240   Aplicativo        A 2023-01-14    NaN          279.200
# 79548    124585       Mobile        A 2023-04-21    NaN         2051.240
# 80016    104235   Aplicativo        A 2023-04-17    NaN         1199.200
#
#            Nome_Departamento estado  cliente_Log
# ...

# %%
#Substituir valores pela média da coluna

media_preco = retail["Preço"].mean()

retail["Preço"].fillna(preco, inplace = True)

# %%
#Exibir que eram nulos e foram substituidos
retail.filter(items = [96], axis=0)
# Out:
#     idcompra idcanalvenda bandeira       Data       Preço  Preço_com_frete  \
# 96    382380     Internet        A 2023-04-26  906.589129            879.2
#
#         Nome_Departamento estado  cliente_Log
# 96  Telefones e Celulares     MS         5804

# %%
#Substituir valores pela mediana da coluna

mediana_preco = retail["Preço"].median()

retail["Preço"].fillna(mediana_preco, inplace = True)

# %%
#Substituir valores pela moda da coluna

moda_preco = retail["Preço"].mode()

retail["Preço"].fillna(moda_preco, inplace = True)

# %%
retail.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055          APP        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
#
#        Nome_Departamento estado  cliente_Log
# 0  Telefones e Celulares     SP        15042
# 1                Tablets     SP        17590
# 2                  Bebes     SP        15478
# 3       TVs e Acessorios     SP         2933
# 4        Esporte e Lazer     RS        19790

# %%
#Alguns filtros - E
retail[(retail["idcanalvenda"]=="Mobile") & (retail["Nome_Departamento"]=="Telefones e Celulares")]

# %%
#Alguns filtros - E - Usando o query
retail.query('idcanalvenda == "Mobile" and Nome_Departamento == "Telefones e Celulares"')
# Out:
#        idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0        393835       Mobile        A 2023-03-05  1582.560          791.280
# 30         4025       Mobile        B 2023-02-10   959.200          959.200
# 51       209430       Mobile        B 2023-04-08  1367.280         1367.280
# 61       452305       Mobile        B 2023-02-21  1359.200         1359.200
# 81       131495       Mobile        B 2023-04-20  1359.200         1359.200
# ...         ...          ...      ...        ...       ...              ...
# 80191    407115       Mobile        B 2023-03-16   863.280          863.280
# 80195    104360       Mobile        B 2023-02-20  1359.200         1359.200
# 80198    216435       Mobile        B 2023-04-13   519.200          519.200
# 80208    306580       Mobile        B 2023-04-16   879.200          879.200
# 80209    421775       Mobile        B 2023-01-03   710.224          710.224
#
#            Nome_Departamento estado  cliente_Log
# ...

# %%
#Alguns filtros - OU
retail[(retail["estado"]=="SP") | (retail["estado"]=="PE")]
# Out:
#        idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0        393835       Mobile        A 2023-03-05  1582.560          791.280
# 1        411885       Mobile        A 2023-03-17   679.200          679.200
# 2        437305       Mobile        A 2023-03-06    35.920           37.512
# 3        440055          APP        A 2023-01-13  2239.416         2239.416
# 5        456225     Internet        A 2023-03-19  1903.200         1903.200
# ...         ...          ...      ...        ...       ...              ...
# 80202     48160   Aplicativo        B 2023-04-30  1359.200         1359.200
# 80204     68870   Aplicativo        B 2023-03-25  1431.200         1431.200
# 80205    135795   Aplicativo        B 2023-02-03  1431.200         1431.200
# 80209    421775       Mobile        B 2023-01-03   710.224          710.224
# 80220    572070   Aplicativo        B 2023-01-06   879.200          879.200
#
#            Nome_Departamento estado  cliente_Log
# ...

# %%
#Alguns filtros - OU - Usando o query
retail.query('estado == "SP" or estado == "PE"')
# Out:
#        idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0        393835       Mobile        A 2023-03-05  1582.560          791.280
# 1        411885       Mobile        A 2023-03-17   679.200          679.200
# 2        437305       Mobile        A 2023-03-06    35.920           37.512
# 3        440055          APP        A 2023-01-13  2239.416         2239.416
# 5        456225     Internet        A 2023-03-19  1903.200         1903.200
# ...         ...          ...      ...        ...       ...              ...
# 80202     48160   Aplicativo        B 2023-04-30  1359.200         1359.200
# 80204     68870   Aplicativo        B 2023-03-25  1431.200         1431.200
# 80205    135795   Aplicativo        B 2023-02-03  1431.200         1431.200
# 80209    421775       Mobile        B 2023-01-03   710.224          710.224
# 80220    572070   Aplicativo        B 2023-01-06   879.200          879.200
#
#            Nome_Departamento estado  cliente_Log
# ...

# %%
#Removendo duplicadas
retail.drop_duplicates(inplace = True)

# %%
#Selecionar determinadas colunas 
var_num = retail[["idcanalvenda","Data","estado"]]
var_num.head()
# Out:
#   idcanalvenda       Data estado
# 0       Mobile 2023-03-05     SP
# 1       Mobile 2023-03-17     SP
# 2       Mobile 2023-03-06     SP
# 3          APP 2023-01-13     SP
# 4       Mobile 2023-03-31     RS

# %% [markdown]
# ## Funções de agregação

# %%
#Agrupar colunas
media_preco_frete = retail["Preço_com_frete"].mean()
media_preco_frete
round(media_preco_frete, 2)
# Out:
# 908.62

# %%
#Agrupar por uma coluna e dar a média das demais
agg_preco_estado = retail.groupby(['estado']).agg('mean').reset_index()
agg_preco_estado[["estado","Preço","Preço_com_frete"]]
# Out:
# <ipython-input-152-fe900fd5d04d>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   agg_preco_estado = retail.groupby(['estado']).agg('mean').reset_index()
#    estado        Preço  Preço_com_frete
# 0      AC   618.416000       623.895200
# 1      AL   974.423654       977.788450
# 2      AM   982.429333       984.228267
# 3      AP   826.106667       828.746667
# 4      BA   945.061339       947.076936
# 5      CE   836.551358       839.772297
# 6      DF   910.418134       911.727411
# 7      ES   876.313630       879.392882
# 8      GO   878.853465       881.249104
# 9      MA  1035.260093      1037.004775
# 10     MG   922.587177       924.456904
# 11     MS   906.589129       887.290278
# 12     MT   886.632627       889.393208
# 13     PA   873.725407       877.674815
# ...

# %%
#Agrupar uma coluna
agg_estado_preco = retail.groupby(['estado'])['Preço'].agg('mean').reset_index()
agg_estado_preco
# Out:
#    estado        Preço
# 0      AC   618.416000
# 1      AL   974.423654
# 2      AM   982.429333
# 3      AP   826.106667
# 4      BA   945.061339
# 5      CE   836.551358
# 6      DF   910.418134
# 7      ES   876.313630
# 8      GO   878.853465
# 9      MA  1035.260093
# 10     MG   922.587177
# 11     MS   906.589129
# 12     MT   886.632627
# 13     PA   873.725407
# 14     PB   873.075403
# 15     PE   932.283524
# 16     PI   973.296939
# 17     PR   878.100779
# 18     RJ   910.674112
# 19     RN   869.773793
# 20     RO   895.949333
# 21     RR   425.947429
# 22     RS   906.835142
# 23     SC   915.214041
# 24     SE   925.906776
# 25     SP   900.728830
# 26     TO   868.131089

# %%
#Agrupar uma coluna
agg_data_preco = retail.groupby(['Data'])['Preço_com_frete'].agg('mean').reset_index()
agg_data_preco
# Out:
#           Data  Preço_com_frete
# 0   2023-01-02       885.823067
# 1   2023-01-03       958.423474
# 2   2023-01-04       951.791589
# 3   2023-01-05       919.507000
# 4   2023-01-06       829.067575
# ..         ...              ...
# 114 2023-04-26       959.497199
# 115 2023-04-27       893.361482
# 116 2023-04-28       930.221305
# 117 2023-04-29       934.728314
# 118 2023-04-30       974.655845
#
# [119 rows x 2 columns]

# %%
#Agrupar uma coluna pela soma
agg_data_preco_soma = retail.groupby(['Data'])['Preço_com_frete'].agg('sum').reset_index()
agg_data_preco_soma
# Out:
#           Data  Preço_com_frete
# 0   2023-01-02       592615.632
# 1   2023-01-03       582721.472
# 2   2023-01-04       648170.072
# 3   2023-01-05       617908.704
# 4   2023-01-06       562107.816
# ..         ...              ...
# 114 2023-04-26       678364.520
# 115 2023-04-27       641433.544
# 116 2023-04-28       610225.176
# 117 2023-04-29       643093.080
# 118 2023-04-30       653994.072
#
# [119 rows x 2 columns]

# %%
#Agrupar uma coluna
agg_canal_preco = retail.groupby(['idcanalvenda'])['Preço_com_frete'].agg('mean').reset_index()
agg_canal_preco
# Out:
#   idcanalvenda  Preço_com_frete
# 0          APP       876.385957
# 1   Aplicativo       927.202475
# 2     Internet       978.195292
# 3       Mobile       823.708258

# %%
#Agrupar mais de uma coluna
agg_estado_canal_preco = retail.groupby(['estado','idcanalvenda'])['Preço_com_frete'].agg('mean').reset_index()
agg_estado_canal_preco
# Out:
#    estado idcanalvenda  Preço_com_frete
# 0      AC   Aplicativo       713.921600
# 1      AC     Internet       163.560000
# 2      AC       Mobile       780.741333
# 3      AL          APP       572.720000
# 4      AL   Aplicativo      1038.396377
# ..    ...          ...              ...
# 94     SP     Internet       962.114362
# 95     SP       Mobile       822.752812
# 96     TO   Aplicativo       784.353600
# 97     TO     Internet       964.057778
# 98     TO       Mobile       863.226133
#
# [99 rows x 3 columns]

# %%
#Agrupar a mesma coluna por diversas métricas

grouped_single = retail.groupby('idcanalvenda').agg({'Preço_com_frete': ['mean', 'min', 'max']})
grouped_single
# Out:
#              Preço_com_frete
#                         mean    min       max
# idcanalvenda
# APP               876.385957  31.20   6799.20
# Aplicativo        927.202475   7.92  14439.24
# Internet          978.195292   8.00  14439.24
# Mobile            823.708258   6.32  14407.12

# %%
#Agrupar mais de uma coluna

retail.groupby('idcanalvenda').agg(
             Preço_media = ('Preço', 'mean'),
             Preço_com_frete_media = ('Preço_com_frete', 'mean'))
# Out:
#               Preço_media  Preço_com_frete_media
# idcanalvenda
# APP           1161.830101             876.385957
# Aplicativo     924.392340             927.202475
# Internet       976.052735             978.195292
# Mobile         821.034682             823.708258

# %% [markdown]
# ##NUMPY

# %%
#Soma de uma coluna da tabela
np.sum(retail["custo_produto"])

# %% [markdown]
# ## MatPlotLib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Gráfico de barra

# %%
fig = plt.figure(figsize=(10, 8))

plt.bar(agg_estado_canal_preco['estado'], agg_estado_canal_preco['Preço_com_frete'], color = 'green',  width = 0.5)

plt.ylabel('Preço')



plt.title('Preço', loc = 'center',fontsize = 18, fontweight = 'bold', color = 'green')
# Out:
# Text(0.5, 1.0, 'Preço')

# %%
fig = plt.figure()

plt.barh(agg_estado_canal_preco['idcanalvenda'], agg_estado_canal_preco['Preço_com_frete'])

plt.ylabel('Preço')

plt.title('Preço', loc = 'center',fontsize = 18, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Preço')

# %% [markdown]
# # Histograma

# %%
fig = plt.figure(figsize=(8, 5))
plt.xticks([100, 200, 300])
plt.yticks([250, 1000, 1750])

plt.hist(retail['Preço_com_frete'], edgecolor="red",color = 'green', bins=20)
plt.show()

# %% [markdown]
# ## Linha

# %%
fig = plt.figure(figsize=(12, 6))
plt.xlabel("Data da compra")
plt.ylabel("Custo do Produto")
x = agg_data_preco['Data']
y = agg_data_preco['Preço_com_frete']

plt.plot(x,y, color = 'green', linewidth = '2')
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
plt.xlabel("Data da compra")
plt.ylabel("Custo do Produto")
x = agg_data_preco_soma['Data']
y = agg_data_preco_soma['Preço_com_frete']

plt.plot(x,y, color = 'green', linewidth = '2')
plt.show()

# %% [markdown]
# ##Scatter Plot

# %%
retail.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055          APP        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
#
#        Nome_Departamento estado  cliente_Log
# 0  Telefones e Celulares     SP        15042
# 1                Tablets     SP        17590
# 2                  Bebes     SP        15478
# 3       TVs e Acessorios     SP         2933
# 4        Esporte e Lazer     RS        19790

# %%
x = retail['Preço']
y = retail['Preço_com_frete']
plt.scatter(x,y)

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# <ipython-input-175-264c6d933df3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %%
sns.set(rc = {'figure.figsize':(10,6)})
ax = sns.barplot(x='idcanalvenda',y='Preço_com_frete', color='blue', capsize= 0, data= agg_estado_canal_preco)

# %%
sns.set(rc = {'figure.figsize':(10,6)})

sns.lineplot(x = "Data", y = "Preço_com_frete", data = retail, err_style="bars")
plt.show()

# %%
sns.set(style="darkgrid")

sns.histplot(data=retail, x="Preço_com_frete",kde=True,bins=20,color='green',element='step')
#poly/bars
plt.show()

# %%
agg_data_preco.head()
# Out:
#         Data  Preço_com_frete
# 0 2023-01-02       885.823067
# 1 2023-01-03       958.423474
# 2 2023-01-04       951.791589
# 3 2023-01-05       919.507000
# 4 2023-01-06       829.067575

# %%
sns.scatterplot(data=retail, x = 'Preço', y = 'Preço_com_frete', hue = 'bandeira')
plt.show()

# %% [markdown]
# ##União entre tabelas

# %%
import numpy as np

# %%
cliente = pd.read_excel("cliente_varejo.xlsx")
cliente.head()
# Out:
#    cliente_Log  idade  renda
# 0        15042     89  11337
# 1        17590     54   2050
# 2        15478     47   8258
# 3         2933     39   4671
# 4        19790     26   9207

# %%
retail.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055          APP        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
#
#        Nome_Departamento estado  cliente_Log
# 0  Telefones e Celulares     SP        15042
# 1                Tablets     SP        17590
# 2                  Bebes     SP        15478
# 3       TVs e Acessorios     SP         2933
# 4        Esporte e Lazer     RS        19790

# %%
varejo_cliente = retail.merge(cliente, how="left", on="cliente_Log")
varejo_cliente.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055          APP        A 2023-01-13  2239.416         2239.416
# 4    440055          APP        A 2023-01-13  2239.416         2239.416
#
#        Nome_Departamento estado  cliente_Log  idade  renda
# 0  Telefones e Celulares     SP        15042     89  11337
# 1                Tablets     SP        17590     54   2050
# 2                  Bebes     SP        15478     47   8258
# 3       TVs e Acessorios     SP         2933     39   4671
# 4       TVs e Acessorios     SP         2933     53  11717

# %%
#Criar ranges de renda e idade de clientes

varejo_cliente['range_idade'] = np.where(varejo_cliente['idade']<=30, 'Até_30',
                   np.where(varejo_cliente['idade']<=50, 'Até_50', 'Maior_de_50'))

varejo_cliente['range_renda'] = np.where(varejo_cliente['renda']<=4000, 'Até_4000',
                   np.where(varejo_cliente['renda']<=10000, 'Até_10000', 'Maior_que_10000'))

varejo_cliente.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055          APP        A 2023-01-13  2239.416         2239.416
# 4    440055          APP        A 2023-01-13  2239.416         2239.416
#
#        Nome_Departamento estado  cliente_Log  idade  renda  range_idade  \
# 0  Telefones e Celulares     SP        15042     89  11337  Maior_de_50
# 1                Tablets     SP        17590     54   2050  Maior_de_50
# 2                  Bebes     SP        15478     47   8258       Até_50
# 3       TVs e Acessorios     SP         2933     39   4671       Até_50
# 4       TVs e Acessorios     SP         2933     53  11717  Maior_de_50
#
#        range_renda
# 0  Maior_que_10000
# 1         Até_4000
# 2        Até_10000
# ...

# %% [markdown]
# ##Plotly

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import math 
X = np.arange(0, math.pi*2, 0.05) 
Y1 = np.sin(X) 
Y2 = np.cos(X) 
Y3 = np.tan(X) 
Y4 = np.tanh(X) 
figure, axis = plt.subplots(2, 2) 
axis[0, 0].plot(X, Y1) 
axis[0, 0].set_title("Sine Function") 
axis[0, 1].plot(X, Y2) 
axis[0, 1].set_title("Cosine Function") 
axis[1, 0].plot(X, Y3) 
axis[1, 0].set_title("Tangent Function") 
axis[1, 1].plot(X, Y4) 
axis[1, 1].set_title("Tanh Function")

# %%
# Instalando as bibliotecas
# %pip install plotly
# %pip install cufflinks
# %pip install chart-studio

# %%
import chart_studio.plotly as py
import cufflinks as cf

import plotly.graph_objects as go
import plotly.express as px

# %%
#Agrupar uma coluna
agg_idade_preco = varejo_cliente.groupby(['range_idade'])['Preço_com_frete'].agg('mean').reset_index()
agg_idade_preco
# Out:
#    range_idade  Preço_com_frete
# 0       Até_30       909.005127
# 1       Até_50       917.588115
# 2  Maior_de_50       911.932517

# %%
# Plotando os dados em barras com o Plotly
px.bar(agg_idade_preco, x='range_idade', y='Preço_com_frete')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Agrupar uma coluna
agg_data_preco = retail.groupby(['Data',"bandeira"])['Preço_com_frete'].agg('mean').reset_index()
agg_data_preco
# Out:
#           Data bandeira  Preço_com_frete
# 0   2023-01-02        A       752.996725
# 1   2023-01-02        B       979.105690
# 2   2023-01-03        A       694.911823
# 3   2023-01-03        B      1114.323037
# 4   2023-01-04        A       760.876250
# ..         ...      ...              ...
# 233 2023-04-28        B      1086.405219
# 234 2023-04-29        A       751.101147
# 235 2023-04-29        B      1054.792231
# 236 2023-04-30        A       675.424496
# 237 2023-04-30        B      1161.584872
#
# [238 rows x 3 columns]

# %%
fig = px.line(agg_data_preco, 
        x='Data', 
        y='Preço_com_frete', 
        color = "bandeira",
        labels={'Data':'Data venda', 'Preço_com_frete':'Preço fim'},
        title='Preços médios por data na visão bandeira')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Box plot
fig = px.box(agg_data_preco, x='bandeira', y='Preço_com_frete', title='Distribuição dos preços por bandeira')
fig.update_traces(line_color='purple')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from plotly.graph_objs import *
layout = Layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)'
)

# %%
# Box plot
fig = px.box(agg_data_preco, x='bandeira', y='Preço_com_frete', title='Distribuição dos preços por bandeira')
fig.update_traces(line_color='purple')

fig = Figure(data=fig, layout=layout)
plot_url = py.plot(fig, filename='transparent-background')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-232-da8f97e48c5e> in <cell line: 6>()
#       4
#       5 fig = Figure(data=fig, layout=layout)
# ----> 6 plot_url = py.plot(fig, filename='transparent-background')
#
# /usr/local/lib/python3.10/dist-packages/chart_studio/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     274             grid_filename = filename + "_grid"
#     275
# --> 276         grid_ops.upload(
#     277             grid=grid,
#     278             filename=grid_filename,
#
# /usr/local/lib/python3.10/dist-packages/chart_studio/plotly/plotly.py in upload(cls, grid, filename, world_readable, auto_open, meta)
#    1085                 payload["parent_path"] = parent_path
#    1086
# -> 1087         file_info = _create_or_overwrite_grid(payload)
#    1088
#    1089         cols = file_info["cols"]
#
# ...
